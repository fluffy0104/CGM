# %%
import pandas as pd

# %%
### This is the first dataset

df_TRADE = pd.read_stata("/Users/cici/Desktop/LMU/WS_2020_21/Machine_Learning/data/TRADHIST_v4.dta.dta")
df_TRADE_Work = df_TRADE.copy()

# %%
### Show all columns 

df_TRADE_Work.columns.values
# Out:
# array(['iso_o', 'iso_d', 'year', 'FLOW', 'FLOW_0', 'SOURCE_TF', 'GDP_o',
#        'SOURCE_GDP_o', 'GDP_d', 'SOURCE_GDP_d', 'SH_PRIM_o',
#        'SOURCE_SH_PRIM_o', 'SH_SECD_o', 'SOURCE_SH_SECD_o', 'SH_PRIM_d',
#        'SOURCE_SH_PRIM_d', 'SH_SECD_d', 'SOURCE_SH_SECD_d', 'POP_o',
#        'POP_d', 'SOURCE_POP_o', 'SOURCE_POP_d', 'IPTOT_o',
#        'SOURCE_IPTOT_o', 'IPTOT_d', 'SOURCE_IPTOT_d', 'XPTOT_o',
#        'SOURCE_XPTOT_o', 'XPTOT_d', 'SOURCE_XPTOT_d', 'BITARIFF',
#        'TARIFF_o', 'SOURCE_TARIFF_o', 'TARIFF_d', 'SOURCE_TARIFF_d',
#        'Distw', 'Dist_coord', 'Dist_o', 'Dist_d', 'SeaDist_SHRT',
#        'SeaDist_2CST', 'Comlang', 'Contig', 'Curcol', 'Metro', 'Colo',
#        'Curcol_o', 'Curcol_d', 'Evercol', 'XCH_RATE_o', 'SOURCE_XCH_o',
#        'XCH_RATE_d', 'SOURCE_XCH_d', 'CONTI_o', 'CONTI_d', 'REGIO_o',
#        'REGIO_d', 'OECD_o', 'OECD_d', 'EU_o', 'EU_d', 'GATT_o', 'GATT_d'],
#       dtype=object)

# %%
### Deleting/dropping certain columns

# del df_TRADE[["SOURCE_TF","SOURCE_GDP_o"]]
df_TRADE_Work.drop(["FLOW_0","SOURCE_TF","SOURCE_GDP_o","SOURCE_GDP_d","SOURCE_IPTOT_o","SOURCE_IPTOT_d","SOURCE_XPTOT_o",
               "SOURCE_XPTOT_d","SOURCE_TARIFF_o","SOURCE_TARIFF_d","Metro","Colo","SOURCE_XCH_o","SOURCE_XCH_d","CONTI_o","CONTI_d",
              "REGIO_o","REGIO_d", "SOURCE_SH_PRIM_o", "SOURCE_SH_SECD_o","SOURCE_SH_PRIM_d",
              "SOURCE_SH_SECD_d","SOURCE_POP_o","SOURCE_POP_d"],axis=1, inplace = True)

# %%
### Check whether it dropped correctly

df_TRADE_Work.columns.values
df_TRADE_Work
# Out:
#         iso_o iso_d  year        FLOW         GDP_o         GDP_d  SH_PRIM_o  \
# 0              ADEN  1950         NaN           NaN           NaN        NaN
# 1              ADEN  1951         NaN           NaN           NaN        NaN
# 2              ADEN  1952         NaN           NaN           NaN        NaN
# 3              ADEN  1953         NaN           NaN           NaN        NaN
# 4              ADEN  1954         NaN           NaN           NaN        NaN
# ...       ...   ...   ...         ...           ...           ...        ...
# 2502422   ZWE   ZMB  2010  46558256.0  6.097825e+09  1.311544e+10  12.281541
# 2502423   ZWE   ZMB  2011  55171376.0  6.838230e+09  1.464204e+10  11.153962
# 2502424   ZWE   ZMB  2012  58787336.0  7.845171e+09  1.614463e+10  11.109810
# 2502425   ZWE   ZMB  2013  77869776.0  8.629172e+09  1.793963e+10  10.111024
# 2502426   ZWE   ZMB  2014  62405360.0  8.627889e+09  1.649053e+10  12.009653
#
# ...

# %%
### To check some entries and confirm that we have do have values from early periods

df_red = df_TRADE_Work[(df_TRADE_Work["iso_o"] == "USA") & (df_TRADE_Work["iso_d"] == "ESP") & (df_TRADE_Work["year"] >= 1910)]

# %%
### Save as Excel, if you want to take a better look at the dataset

# df_red.to_excel(r"C:\Users\andre\Desktop\Jupyter Notebook\hello.xlsx")

# %%
### This is the second dataset

df_price = pd.read_excel("/Users/cici/Desktop/LMU/WS_2020_21/Machine_Learning/data/API_FP.CPI.TOTL.ZG_DS2_en_excel_v2_2055732.xls", sheet_name = "Data")

# %%
### This is how it looks like 

df_price
# Out:
#      Country Name Country Code                         Indicator Name  \
# 0           Aruba          ABW  Inflation, consumer prices (annual %)
# 1     Afghanistan          AFG  Inflation, consumer prices (annual %)
# 2          Angola          AGO  Inflation, consumer prices (annual %)
# 3         Albania          ALB  Inflation, consumer prices (annual %)
# 4         Andorra          AND  Inflation, consumer prices (annual %)
# ..            ...          ...                                    ...
# 259        Kosovo          XKX  Inflation, consumer prices (annual %)
# 260   Yemen, Rep.          YEM  Inflation, consumer prices (annual %)
# 261  South Africa          ZAF  Inflation, consumer prices (annual %)
# 262        Zambia          ZMB  Inflation, consumer prices (annual %)
# 263      Zimbabwe          ZWE  Inflation, consumer prices (annual %)
#
#      Indicator Code      1960      1961     1962      1963     1964      1965  \
# ...

# %%
### Check shape 

df_price.shape
# df_Interest.head()
# Out:
# (264, 65)

# %%
### Easier manipulation

df_price_reduced = df_price

# %%
### Drop certain columns

df_price_reduced.drop(["Country Name", "Indicator Code", "Indicator Name"],axis=1, inplace = True)
# df_price_reduced

# %%
### How it looks like now

df_price_reduced
# Out:
#     Country Code      1960      1961     1962      1963     1964      1965  \
# 0            ABW       NaN       NaN      NaN       NaN      NaN       NaN
# 1            AFG       NaN       NaN      NaN       NaN      NaN       NaN
# 2            AGO       NaN       NaN      NaN       NaN      NaN       NaN
# 3            ALB       NaN       NaN      NaN       NaN      NaN       NaN
# 4            AND       NaN       NaN      NaN       NaN      NaN       NaN
# ..           ...       ...       ...      ...       ...      ...       ...
# 259          XKX       NaN       NaN      NaN       NaN      NaN       NaN
# 260          YEM       NaN       NaN      NaN       NaN      NaN       NaN
# 261          ZAF  1.288878  2.102343  1.24629  1.337968  2.53498  4.069023
# 262          ZMB       NaN       NaN      NaN       NaN      NaN       NaN
# 263          ZWE       NaN       NaN      NaN       NaN      NaN       NaN
#
# ...

# %%
df_price.shape
# df_Interest.head()
# Out:
# (264, 62)

# %%
### Sort of transposing, but only the columns with time values 

df_price_melt_o = df_price_reduced.melt(["Country Code"],var_name = "year",value_name = "API").copy()
dict_name = {"Country Code": "iso_o"}
df_price_melt_o.rename(dict_name, axis = 1, inplace = True)
df_price_melt_o
# Out:
#       iso_o  year  API
# 0       ABW  1960  NaN
# 1       AFG  1960  NaN
# 2       AGO  1960  NaN
# 3       ALB  1960  NaN
# 4       AND  1960  NaN
# ...     ...   ...  ...
# 16099   XKX  2020  NaN
# 16100   YEM  2020  NaN
# 16101   ZAF  2020  NaN
# 16102   ZMB  2020  NaN
# 16103   ZWE  2020  NaN
#
# [16104 rows x 3 columns]

# %%
df_price_melt_o = df_price_melt_o.rename(columns = {"API" : "API_o"})
df_price_melt_o
# Out:
#       iso_o  year  API_o
# 0       ABW  1960    NaN
# 1       AFG  1960    NaN
# 2       AGO  1960    NaN
# 3       ALB  1960    NaN
# 4       AND  1960    NaN
# ...     ...   ...    ...
# 16099   XKX  2020    NaN
# 16100   YEM  2020    NaN
# 16101   ZAF  2020    NaN
# 16102   ZMB  2020    NaN
# 16103   ZWE  2020    NaN
#
# [16104 rows x 3 columns]

# %%
df_price_melt_d = df_price_reduced.melt(["Country Code"],var_name = "year",value_name = "API").copy()
dict_name = {"Country Code": "iso_d"}
df_price_melt_d.rename(dict_name, axis = 1, inplace = True)
df_price_melt_d
# Out:
#       iso_d  year  API
# 0       ABW  1960  NaN
# 1       AFG  1960  NaN
# 2       AGO  1960  NaN
# 3       ALB  1960  NaN
# 4       AND  1960  NaN
# ...     ...   ...  ...
# 16099   XKX  2020  NaN
# 16100   YEM  2020  NaN
# 16101   ZAF  2020  NaN
# 16102   ZMB  2020  NaN
# 16103   ZWE  2020  NaN
#
# [16104 rows x 3 columns]

# %%
df_price_melt_d = df_price_melt_d.rename(columns = {"API" : "API_d"})
df_price_melt_d
# Out:
#       iso_d  year  API_d
# 0       ABW  1960    NaN
# 1       AFG  1960    NaN
# 2       AGO  1960    NaN
# 3       ALB  1960    NaN
# 4       AND  1960    NaN
# ...     ...   ...    ...
# 16099   XKX  2020    NaN
# 16100   YEM  2020    NaN
# 16101   ZAF  2020    NaN
# 16102   ZMB  2020    NaN
# 16103   ZWE  2020    NaN
#
# [16104 rows x 3 columns]

# %%
### It did it correctly because one can double-check the values from this table with the corresponding value in 
### the above original table

df_price_melt_o[df_price_melt_o["iso_o"] == "ESP"]
# Out:
#       iso_o  year     API_o
# 68      ESP  1960  1.177758
# 332     ESP  1961  0.809255
# 596     ESP  1962  5.706487
# 860     ESP  1963  8.743692
# 1124    ESP  1964  6.979251
# ...     ...   ...       ...
# 14852   ESP  2016 -0.202672
# 15116   ESP  2017  1.956083
# 15380   ESP  2018  1.675068
# 15644   ESP  2019  0.699536
# 15908   ESP  2020       NaN
#
# [61 rows x 3 columns]

# %%
df_price_melt_o = df_price_melt_o[df_price_melt_o['API_o'].notna()]
df_price_melt_d = df_price_melt_d[df_price_melt_d['API_d'].notna()]

# %%
df_price_melt_o.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9871 entries, 11 to 15838
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   iso_o   9871 non-null   object
#  1   year    9871 non-null   object
#  2   API_o   9871 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 308.5+ KB

# %%
df_price_melt_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9871 entries, 11 to 15838
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   iso_d   9871 non-null   object
#  1   year    9871 non-null   object
#  2   API_d   9871 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 308.5+ KB

# %%
df_TRADE_Work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2502427 entries, 0 to 2502426
# Data columns (total 39 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   iso_o         object
#  1   iso_d         object
#  2   year          int16
#  3   FLOW          float32
#  4   GDP_o         float32
#  5   GDP_d         float32
#  6   SH_PRIM_o     float32
#  7   SH_SECD_o     float32
#  8   SH_PRIM_d     float32
#  9   SH_SECD_d     float32
#  10  POP_o         float32
#  11  POP_d         float32
#  12  IPTOT_o       float32
#  13  IPTOT_d       float32
#  14  XPTOT_o       float32
#  15  XPTOT_d       float32
#  16  BITARIFF      float32
#  17  TARIFF_o      float32
#  18  TARIFF_d      float32
#  19  Distw         float64
#  20  Dist_coord    float64
#  21  Dist_o        float64
#  22  Dist_d        float64
#  23  SeaDist_SHRT  float32
#  24  SeaDist_2CST  float32
#  25  Comlang       float64
#  26  Contig        float64
#  27  Curcol        float64
# ...

# %%
# NOTE: year is of different data type. In df_price_melt_, year is a object; in df_TRADE_Work, year is integer
# when not changing the data type, merging three datasets will lead to NaN for all values

# %%
df_price_melt_o["year"] = df_price_melt_o.year.astype(int)
df_price_melt_d["year"] = df_price_melt_d.year.astype(int)
# Out:
# <ipython-input-24-05da851d80b8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_price_melt_o["year"] = df_price_melt_o.year.astype(int)
# <ipython-input-24-05da851d80b8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_price_melt_d["year"] = df_price_melt_d.year.astype(int)

# %%
### Joining both datasets (the one with trade data and the other one including API = average price inflation)

#Join_Countries = pd.concat([df_TRADE_Work,df_price_melt],axis=0,join="outer")
#Join_Countries

Join_Countries = pd.merge(df_TRADE_Work, df_price_melt_o, how = 'left', on = ['iso_o', 'year'])
Join_Countries
# Out:
#         iso_o iso_d  year        FLOW         GDP_o         GDP_d  SH_PRIM_o  \
# 0              ADEN  1950         NaN           NaN           NaN        NaN
# 1              ADEN  1951         NaN           NaN           NaN        NaN
# 2              ADEN  1952         NaN           NaN           NaN        NaN
# 3              ADEN  1953         NaN           NaN           NaN        NaN
# 4              ADEN  1954         NaN           NaN           NaN        NaN
# ...       ...   ...   ...         ...           ...           ...        ...
# 2502422   ZWE   ZMB  2010  46558256.0  6.097825e+09  1.311544e+10  12.281541
# 2502423   ZWE   ZMB  2011  55171376.0  6.838230e+09  1.464204e+10  11.153962
# 2502424   ZWE   ZMB  2012  58787336.0  7.845171e+09  1.614463e+10  11.109810
# 2502425   ZWE   ZMB  2013  77869776.0  8.629172e+09  1.793963e+10  10.111024
# 2502426   ZWE   ZMB  2014  62405360.0  8.627889e+09  1.649053e+10  12.009653
#
# ...

# %%
Join_Countries = pd.merge(Join_Countries, df_price_melt_d, how = 'left', on = ['iso_d', 'year'])
Join_Countries
# Out:
#         iso_o iso_d  year        FLOW         GDP_o         GDP_d  SH_PRIM_o  \
# 0              ADEN  1950         NaN           NaN           NaN        NaN
# 1              ADEN  1951         NaN           NaN           NaN        NaN
# 2              ADEN  1952         NaN           NaN           NaN        NaN
# 3              ADEN  1953         NaN           NaN           NaN        NaN
# 4              ADEN  1954         NaN           NaN           NaN        NaN
# ...       ...   ...   ...         ...           ...           ...        ...
# 2502422   ZWE   ZMB  2010  46558256.0  6.097825e+09  1.311544e+10  12.281541
# 2502423   ZWE   ZMB  2011  55171376.0  6.838230e+09  1.464204e+10  11.153962
# 2502424   ZWE   ZMB  2012  58787336.0  7.845171e+09  1.614463e+10  11.109810
# 2502425   ZWE   ZMB  2013  77869776.0  8.629172e+09  1.793963e+10  10.111024
# 2502426   ZWE   ZMB  2014  62405360.0  8.627889e+09  1.649053e+10  12.009653
#
# ...

# %% [markdown]
# It worked correctly. However only for one country and not for the country-pair. Final step consists in re-doing this joining with the other country-column (iso_d). Potentially will also include an interaction term (API_o * API_d).

# %%
# we need to merge df_price_melt_ with Join_Countries one by one, because we want API_o and API_d for each country pair

# %%
Join_Countries['API_od'] = Join_Countries['API_o'] * Join_Countries['API_d']
Join_Countries
# Out:
#         iso_o iso_d  year        FLOW         GDP_o         GDP_d  SH_PRIM_o  \
# 0              ADEN  1950         NaN           NaN           NaN        NaN
# 1              ADEN  1951         NaN           NaN           NaN        NaN
# 2              ADEN  1952         NaN           NaN           NaN        NaN
# 3              ADEN  1953         NaN           NaN           NaN        NaN
# 4              ADEN  1954         NaN           NaN           NaN        NaN
# ...       ...   ...   ...         ...           ...           ...        ...
# 2502422   ZWE   ZMB  2010  46558256.0  6.097825e+09  1.311544e+10  12.281541
# 2502423   ZWE   ZMB  2011  55171376.0  6.838230e+09  1.464204e+10  11.153962
# 2502424   ZWE   ZMB  2012  58787336.0  7.845171e+09  1.614463e+10  11.109810
# 2502425   ZWE   ZMB  2013  77869776.0  8.629172e+09  1.793963e+10  10.111024
# 2502426   ZWE   ZMB  2014  62405360.0  8.627889e+09  1.649053e+10  12.009653
#
# ...

# %%
ghg = pd.read_csv("/Users/cici/Desktop/LMU/WS_2020_21/Machine_Learning/data/GHG.csv")
country_code = pd.read_excel("/Users/cici/Desktop/LMU/WS_2020_21/Machine_Learning/data/country_codes.xls")

# %%
del ghg["category"]

# %%
ghg = ghg.rename(columns = {"value" : "GHG_o"})

# %%
ghg_iso = pd.merge(country_code, ghg)
ghg_iso
# Out:
#      iso_o country_or_area  year          GHG_o
# 0      AUS       Australia  2014  393126.946994
# 1      AUS       Australia  2013  396913.936530
# 2      AUS       Australia  2012  406462.847704
# 3      AUS       Australia  2011  403705.528314
# 4      AUS       Australia  2010  406200.993184
# ...    ...             ...   ...            ...
# 7508   GBR  United Kingdom  1994    1223.437811
# 7509   GBR  United Kingdom  1993    1182.895332
# 7510   GBR  United Kingdom  1992    1358.245640
# 7511   GBR  United Kingdom  1991    1318.537525
# 7512   GBR  United Kingdom  1990    1279.061171
#
# [7513 rows x 4 columns]

# %%
df_trade = pd.merge(ghg_iso, Join_Countries, how = 'left', on = ['iso_o', 'year']) 
df_trade
# Out:
#         iso_o country_or_area  year          GHG_o iso_d          FLOW  \
# 0         AUS       Australia  2014  393126.946994   ABW  1.588223e+05
# 1         AUS       Australia  2014  393126.946994   AFG  4.242004e+06
# 2         AUS       Australia  2014  393126.946994   AGO  6.926177e+06
# 3         AUS       Australia  2014  393126.946994   ALB  1.408524e+06
# 4         AUS       Australia  2014  393126.946994   ARE  1.762192e+09
# ...       ...             ...   ...            ...   ...           ...
# 1370757   GBR  United Kingdom  1990    1279.061171   YEM  7.902499e+07
# 1370758   GBR  United Kingdom  1990    1279.061171   YUG  2.401387e+08
# 1370759   GBR  United Kingdom  1990    1279.061171   ZAF  1.116549e+09
# 1370760   GBR  United Kingdom  1990    1279.061171   ZMB  1.110788e+08
# 1370761   GBR  United Kingdom  1990    1279.061171   ZWE  1.200902e+08
#
#                 GDP_o         GDP_d  SH_PRIM_o  SH_SECD_o  ...  XCH_RATE_d  \
# ...

# %%
df_trade_new = df_trade.copy()
df_trade_new = df_trade.groupby(['iso_o', 'year'])[['FLOW']].sum()
df_trade_new = df_trade_new.rename(columns={'FLOW': 'FLOW_sum'})
df_trade_new
# Out:
#                 FLOW_sum
# iso_o year
# AUS   1990  1.934863e+11
#       1991  1.980439e+11
#       1992  2.012578e+11
#       1993  2.332723e+11
#       1994  2.581625e+11
# ...                  ...
# UKR   2010  2.866809e+11
#       2011  3.217516e+11
#       2012  3.289350e+11
#       2013  3.016552e+11
#       2014  2.518971e+11
#
# [974 rows x 1 columns]

# %%
df_trade_work = pd.merge(df_trade, df_trade_new, how = 'left', on = ['iso_o', 'year'])
df_trade_work
# Out:
#         iso_o country_or_area  year          GHG_o iso_d          FLOW  \
# 0         AUS       Australia  2014  393126.946994   ABW  1.588223e+05
# 1         AUS       Australia  2014  393126.946994   AFG  4.242004e+06
# 2         AUS       Australia  2014  393126.946994   AGO  6.926177e+06
# 3         AUS       Australia  2014  393126.946994   ALB  1.408524e+06
# 4         AUS       Australia  2014  393126.946994   ARE  1.762192e+09
# ...       ...             ...   ...            ...   ...           ...
# 1370757   GBR  United Kingdom  1990    1279.061171   YEM  7.902499e+07
# 1370758   GBR  United Kingdom  1990    1279.061171   YUG  2.401387e+08
# 1370759   GBR  United Kingdom  1990    1279.061171   ZAF  1.116549e+09
# 1370760   GBR  United Kingdom  1990    1279.061171   ZMB  1.110788e+08
# 1370761   GBR  United Kingdom  1990    1279.061171   ZWE  1.200902e+08
#
#                 GDP_o         GDP_d  SH_PRIM_o  SH_SECD_o  ...  OECD_o  \
# ...

# %%
df_trade_work["FLOW_pct"] = (df_trade_work["FLOW"] / df_trade_work["FLOW_sum"])

# %%
df_trade_work["GHG_od"] = (df_trade_work["GHG_o"] * df_trade_work["FLOW_pct"])

# %%
df_trade_work
# Out:
#         iso_o country_or_area  year          GHG_o iso_d          FLOW  \
# 0         AUS       Australia  2014  393126.946994   ABW  1.588223e+05
# 1         AUS       Australia  2014  393126.946994   AFG  4.242004e+06
# 2         AUS       Australia  2014  393126.946994   AGO  6.926177e+06
# 3         AUS       Australia  2014  393126.946994   ALB  1.408524e+06
# 4         AUS       Australia  2014  393126.946994   ARE  1.762192e+09
# ...       ...             ...   ...            ...   ...           ...
# 1370757   GBR  United Kingdom  1990    1279.061171   YEM  7.902499e+07
# 1370758   GBR  United Kingdom  1990    1279.061171   YUG  2.401387e+08
# 1370759   GBR  United Kingdom  1990    1279.061171   ZAF  1.116549e+09
# 1370760   GBR  United Kingdom  1990    1279.061171   ZMB  1.110788e+08
# 1370761   GBR  United Kingdom  1990    1279.061171   ZWE  1.200902e+08
#
#                 GDP_o         GDP_d  SH_PRIM_o  SH_SECD_o  ...  EU_o  EU_d  \
# ...

# %%
percent_missing = df_trade_work.isnull().sum() * 100 / len(df_trade_work)
percent_missing
# Out:
# iso_o                0.000000
# country_or_area      0.000000
# year                 0.000000
# GHG_o                0.000000
# iso_d                0.021667
# FLOW                 4.547398
# GDP_o                1.233620
# GDP_d                6.998005
# SH_PRIM_o           12.397776
# SH_SECD_o           11.267456
# SH_PRIM_d           16.016055
# SH_SECD_d           15.858989
# POP_o                0.021667
# POP_d                2.838275
# IPTOT_o              5.013927
# IPTOT_d              2.614604
# XPTOT_o              4.626113
# XPTOT_d              2.386191
# BITARIFF           100.000000
# TARIFF_o            86.277414
# TARIFF_d            97.114160
# Distw                3.682915
# Dist_coord           0.032172
# Dist_o               0.021667
# Dist_d               0.032172
# SeaDist_SHRT        28.322057
# SeaDist_2CST        28.322057
# Comlang              0.032172
# Contig               0.032172
# Curcol               0.032172
# Curcol_o             0.032172
# ...

# %%
df_trade_work1 = df_trade_work.copy()
df_trade_work1 = df_trade_work1.drop(['BITARIFF', 'TARIFF_o', 'TARIFF_d', 'FLOW_pct'], axis=1)

# %%
df_trade_work1 = df_trade_work1[df_trade_work1['GDP_o'].notna()]

# %%
df_trade_work1 = df_trade_work1[df_trade_work1['GDP_d'].notna()]

# %%
df_trade_work1 = df_trade_work1[df_trade_work1['FLOW'].notna()]

# %%
df_trade_work1 = df_trade_work1[df_trade_work1['IPTOT_o'].notna()]

# %%
df_trade_work1 = df_trade_work1[df_trade_work1['IPTOT_d'].notna()]

# %%
df_trade_work1 = df_trade_work1[df_trade_work1['XPTOT_o'].notna()]

# %%
df_trade_work1 = df_trade_work1[df_trade_work1['XPTOT_d'].notna()]

# %%
df_trade_work1 = df_trade_work1[df_trade_work1['SeaDist_SHRT'].notna()]

# %%
df_trade_work1 = df_trade_work1[df_trade_work1['SeaDist_2CST'].notna()]

# %%
df_trade_work1 = df_trade_work1[df_trade_work1['XCH_RATE_o'].notna()]

# %%
df_trade_work1 = df_trade_work1[df_trade_work1['XCH_RATE_d'].notna()]

# %%
df_trade_work1 = df_trade_work1[df_trade_work1['Distw'].notna()]

# %%
df_trade_work1 = df_trade_work1[df_trade_work1['API_d'].notna()]

# %%
df_trade_work1
# Out:
#         iso_o country_or_area  year          GHG_o iso_d          FLOW  \
# 195       AUS       Australia  2013  396913.936530   AFG  4.561007e+06
# 196       AUS       Australia  2013  396913.936530   AGO  5.870578e+06
# 202       AUS       Australia  2013  396913.936530   AUT  3.899438e+07
# 205       AUS       Australia  2013  396913.936530   BEL  1.111859e+09
# 209       AUS       Australia  2013  396913.936530   BGR  1.246930e+08
# ...       ...             ...   ...            ...   ...           ...
# 1370746   GBR  United Kingdom  1990    1279.061171   TZA  9.846699e+07
# 1370748   GBR  United Kingdom  1990    1279.061171   URY  2.205683e+07
# 1370749   GBR  United Kingdom  1990    1279.061171   USA  1.178820e+10
# 1370759   GBR  United Kingdom  1990    1279.061171   ZAF  1.116549e+09
# 1370760   GBR  United Kingdom  1990    1279.061171   ZMB  1.110788e+08
#
#                 GDP_o         GDP_d  SH_PRIM_o  SH_SECD_o  ...  OECD_d  EU_o  \
# ...

# %%
# dataset do not contain NaN other than SH_PRIM_ and SH_SECD_

# %%
# check the distribution of GDP_

# %%
import matplotlib.pyplot as plt

x = df_trade_work1['GDP_o']
plt.hist(x, bins=10)
plt.show()

# %%
x = df_trade_work1['GDP_d']
plt.hist(x, bins=10)
plt.show()

# %%
df_trade_work1['log(GDP_o)'] = np.log10(df_trade_work1['GDP_o'])

# %%
df_trade_work1['log(GDP_d)'] = np.log10(df_trade_work1['GDP_d'])

# %%
x = df_trade_work1['FLOW']
plt.hist(x, bins=10)
plt.show()

# %%
df_trade_work1['log(FLOW)'] = np.log10(df_trade_work1['FLOW'] + 1)

# %%
x = df_trade_work1['GHG_o']
plt.hist(x, bins=10)
plt.show()

# %%
df_trade_work1['log(XPTOT_o)'] = np.log10(df_trade_work1['XPTOT_o'] + 1)
df_trade_work1['log(XPTOT_d)'] = np.log10(df_trade_work1['XPTOT_d'] + 1)
df_trade_work1['log(IPTOT_o)'] = np.log10(df_trade_work1['IPTOT_o'] + 1)
df_trade_work1['log(IPTOT_d)'] = np.log10(df_trade_work1['IPTOT_d'] + 1)
df_trade_work1['log(POP_o)'] = np.log10(df_trade_work1['POP_o'] + 1)
df_trade_work1['log(POP_d)'] = np.log10(df_trade_work1['POP_d'] + 1)
df_trade_work1['log(Dist_d)'] = np.log10(df_trade_work1['Dist_d'] + 1)
df_trade_work1['log(Dist_o)'] = np.log10(df_trade_work1['Dist_o'] + 1)
df_trade_work1['log(Distw)'] = np.log10(df_trade_work1['Distw'] + 1)
df_trade_work1['log(Dist_coord)'] = np.log10(df_trade_work1['Dist_coord'] + 1)
df_trade_work1['log(SeaDist_SHRT)'] = np.log10(df_trade_work1['SeaDist_SHRT'] + 1)
df_trade_work1['log(SeaDist_2CST)'] = np.log10(df_trade_work1['SeaDist_2CST'] + 1)
df_trade_work1['log(XCH_RATE_o)'] = np.log10(df_trade_work1['XCH_RATE_o'] + 1)
df_trade_work1['log(XCH_RATE_d)'] = np.log10(df_trade_work1['XCH_RATE_d'] + 1)
df_trade_work1['log(GHG_od)'] = np.log10(df_trade_work1['GHG_o'] + 1)

# %%
df_trade_work1
# Out:
#         iso_o country_or_area  year          GHG_o iso_d          FLOW  \
# 195       AUS       Australia  2013  396913.936530   AFG  4.561007e+06
# 196       AUS       Australia  2013  396913.936530   AGO  5.870578e+06
# 202       AUS       Australia  2013  396913.936530   AUT  3.899438e+07
# 205       AUS       Australia  2013  396913.936530   BEL  1.111859e+09
# 209       AUS       Australia  2013  396913.936530   BGR  1.246930e+08
# ...       ...             ...   ...            ...   ...           ...
# 1370746   GBR  United Kingdom  1990    1279.061171   TZA  9.846699e+07
# 1370748   GBR  United Kingdom  1990    1279.061171   URY  2.205683e+07
# 1370749   GBR  United Kingdom  1990    1279.061171   USA  1.178820e+10
# 1370759   GBR  United Kingdom  1990    1279.061171   ZAF  1.116549e+09
# 1370760   GBR  United Kingdom  1990    1279.061171   ZMB  1.110788e+08
#
#                 GDP_o         GDP_d  SH_PRIM_o  SH_SECD_o  ...  log(POP_d)  \
# ...

# %%
x = df_trade_work1['year']
y = df_trade_work1['FLOW_sum']

fig, ax = plt.subplots()  
ax.plot(x, y)  
ax.set_xlabel('year') 
ax.set_ylabel('FLow')  
ax.set_title("Simple Plot")
# Out:
# Text(0.5, 1.0, 'Simple Plot')

# %%
# probably trade flow in each country is persistent over time (linearity presents in data)
# ML better deal with nonlinear trend

# %%
cols = ['iso_o', 'iso_d', 'year', 'log(FLOW)', 'log(GDP_o)', 'log(GDP_d)', 'log(POP_o)', 'log(POP_d)','log(IPTOT_o)','log(IPTOT_d)', 'log(XPTOT_o)', 'log(XPTOT_d)', 'log(XCH_RATE_o)', 'log(XCH_RATE_d)', 'log(Distw)', 'log(Dist_coord)', 'log(Dist_o)', 'log(Dist_d)', 'log(SeaDist_SHRT)', 'log(SeaDist_2CST)', 'Comlang', 'Contig', 'Curcol_o', 'Curcol_d', 'Curcol', 'Evercol', 'OECD_o', 'OECD_d', 'EU_o', 'EU_d', 'GATT_o', 'GATT_d', 'API_o', 'API_d', 'API_od', 'log(GHG_od)']
df_trade_work_ols1 = df_trade_work1.copy()
df_trade_work_ols1 = df_trade_work_ols1[cols]

# %%
df_trade_work = df_trade_work[df_trade_work['GHG_od'].notna()]

# %%
df_trade_work = df_trade_work[df_trade_work['GDP_o'].notna()]

# %%
df_trade_work = df_trade_work[df_trade_work['GDP_d'].notna()]

# %%
df_trade_work = df_trade_work[df_trade_work['IPTOT_o'].notna()]

# %%
df_trade_work = df_trade_work[df_trade_work['IPTOT_d'].notna()]

# %%
df_trade_work = df_trade_work[df_trade_work['SH_PRIM_o'].notna()]

# %%
df_trade_work = df_trade_work[df_trade_work['SH_PRIM_d'].notna()]

# %%
df_trade_work = df_trade_work[df_trade_work['TARIFF_o'].notna()]

# %%
df_trade_work = df_trade_work[df_trade_work['TARIFF_d'].notna()]

# %%
# we can not include bitariff in this case

#df_trade_work = df_trade_work[df_trade_work['BITARIFF'].notna()]
#df_trade_work
# Out:
# Empty DataFrame
# Columns: [iso_o, country_or_area, year, GHG_o, iso_d, FLOW, GDP_o, GDP_d, SH_PRIM_o, SH_SECD_o, SH_PRIM_d, SH_SECD_d, POP_o, POP_d, IPTOT_o, IPTOT_d, XPTOT_o, XPTOT_d, BITARIFF, TARIFF_o, TARIFF_d, Distw, Dist_coord, Dist_o, Dist_d, SeaDist_SHRT, SeaDist_2CST, Comlang, Contig, Curcol, Curcol_o, Curcol_d, Evercol, XCH_RATE_o, XCH_RATE_d, OECD_o, OECD_d, EU_o, EU_d, GATT_o, GATT_d, API_o, API_d, API_od, FLOW_sum, FLOW_pct, GHG_od]
# Index: []
#
# [0 rows x 47 columns]

# %%
df_trade_work = df_trade_work[df_trade_work['XCH_RATE_o'].notna()]

# %%
df_trade_work = df_trade_work[df_trade_work['XCH_RATE_d'].notna()]
df_trade_work
# Out:
#         iso_o country_or_area  year         GHG_o iso_d          FLOW  \
# 289140    DNK         Denmark  1997  65457.834843   ESP  5.927132e+08
# 289146    DNK         Denmark  1997  65457.834843   FRA  1.358719e+09
# 289149    DNK         Denmark  1997  65457.834843   GBR  1.959397e+09
# 289157    DNK         Denmark  1997  65457.834843   GRC  2.444199e+08
# 289217    DNK         Denmark  1997  65457.834843   NLD  9.613337e+08
# ...       ...             ...   ...           ...   ...           ...
# 1370457   GBR  United Kingdom  1991   1318.537525   FRA  9.749256e+09
# 1370522   GBR  United Kingdom  1991   1318.537525   NLD  6.182051e+09
# 1370626   GBR  United Kingdom  1990   1279.061171   DNK  1.332809e+09
# 1370636   GBR  United Kingdom  1990   1279.061171   FRA  9.520620e+09
# 1370701   GBR  United Kingdom  1990   1279.061171   NLD  5.806918e+09
#
#                 GDP_o         GDP_d  SH_PRIM_o  SH_SECD_o  ...  EU_o  EU_d  \
# ...

# %%
df_trade_work = df_trade_work.drop(['BITARIFF','FLOW_sum', 'FLOW_pct'], axis=1)

# %%
df_trade_work.columns.values
# Out:
# array(['iso_o', 'country_or_area', 'year', 'GHG_o', 'iso_d', 'FLOW',
#        'GDP_o', 'GDP_d', 'SH_PRIM_o', 'SH_SECD_o', 'SH_PRIM_d',
#        'SH_SECD_d', 'POP_o', 'POP_d', 'IPTOT_o', 'IPTOT_d', 'XPTOT_o',
#        'XPTOT_d', 'TARIFF_o', 'TARIFF_d', 'Distw', 'Dist_coord', 'Dist_o',
#        'Dist_d', 'SeaDist_SHRT', 'SeaDist_2CST', 'Comlang', 'Contig',
#        'Curcol', 'Curcol_o', 'Curcol_d', 'Evercol', 'XCH_RATE_o',
#        'XCH_RATE_d', 'OECD_o', 'OECD_d', 'EU_o', 'EU_d', 'GATT_o',
#        'GATT_d', 'API_o', 'API_d', 'API_od', 'GHG_od'], dtype=object)

# %%
# first looking at ols

cols = ['iso_o', 'iso_d', 'year', 'FLOW', 'GDP_o', 'GDP_d', 'POP_o', 'POP_d','IPTOT_o','IPTOT_d', 'XPTOT_o', 'XPTOT_d', 'SH_PRIM_o', 'SH_SECD_o', 'SH_PRIM_d', 'SH_SECD_d', 'TARIFF_o', 'TARIFF_d', 'XCH_RATE_o', 'XCH_RATE_d', 'Distw', 'Dist_coord', 'Dist_o', 'Dist_d', 'SeaDist_SHRT', 'SeaDist_2CST', 'Comlang', 'Contig', 'Curcol_o', 'Curcol_d', 'Curcol', 'Evercol', 'OECD_o', 'OECD_d', 'EU_o', 'EU_d', 'GATT_o', 'GATT_d', 'API_o', 'API_d', 'API_od', 'GHG_od']
df_trade_work_ols = df_trade_work.copy()
df_trade_work_ols = df_trade_work_ols[cols]
df_trade_work_ols
# Out:
#         iso_o iso_d  year          FLOW         GDP_o         GDP_d  \
# 289140    DNK   ESP  1997  5.927132e+08  1.060030e+11  3.595943e+11
# 289146    DNK   FRA  1997  1.358719e+09  1.060030e+11  8.922538e+11
# 289149    DNK   GBR  1997  1.959397e+09  1.060030e+11  8.835401e+11
# 289157    DNK   GRC  1997  2.444199e+08  1.060030e+11  8.744582e+10
# 289217    DNK   NLD  1997  9.613337e+08  1.060030e+11  2.517860e+11
# ...       ...   ...   ...           ...           ...           ...
# 1370457   GBR   FRA  1991  9.749256e+09  6.479831e+11  7.232636e+11
# 1370522   GBR   NLD  1991  6.182051e+09  6.479831e+11  1.833275e+11
# 1370626   GBR   DNK  1990  1.332809e+09  6.156479e+11  7.777185e+10
# 1370636   GBR   FRA  1990  9.520620e+09  6.156479e+11  7.182199e+11
# 1370701   GBR   NLD  1990  5.806918e+09  6.156479e+11  1.769883e+11
#
#                 POP_o         POP_d       IPTOT_o       IPTOT_d  ...  OECD_o  \
# ...

# %%
dummies = [pd.get_dummies(df_trade_work_ols[i], prefix=i, drop_first = True) for i in ['iso_o', 'iso_d', 'year']]

df_trade_work_ols['c'] = 1

df_trade_work_ols
# Out:
#         iso_o iso_d  year          FLOW         GDP_o         GDP_d  \
# 0         AUS   ABW  2014  1.588223e+05  8.840499e+11           NaN
# 1         AUS   AFG  2014  4.242004e+06  8.840499e+11  1.218510e+10
# 2         AUS   AGO  2014  6.926177e+06  8.840499e+11  7.704505e+10
# 3         AUS   ALB  2014  1.408524e+06  8.840499e+11  8.069417e+09
# 4         AUS   ARE  2014  1.762192e+09  8.840499e+11  2.427585e+11
# ...       ...   ...   ...           ...           ...           ...
# 1370757   GBR   YEM  1990  7.902499e+07  6.156479e+11  3.180402e+09
# 1370758   GBR   YUG  1990  2.401387e+08  6.156479e+11  5.924622e+10
# 1370759   GBR   ZAF  1990  1.116549e+09  6.156479e+11  6.308418e+10
# 1370760   GBR   ZMB  1990  1.110788e+08  6.156479e+11  1.851941e+09
# 1370761   GBR   ZWE  1990  1.200902e+08  6.156479e+11  4.946844e+09
#
#                 POP_o         POP_d       IPTOT_o       IPTOT_d  ...  OECD_d  \
# ...

# %%
# out-of-sample prediction using linear regression
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler 
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split


y = df_trade_work_ols['FLOW']
X = df_trade_work_ols.iloc[:, 4:].join(dummies)
X = pd.DataFrame(np.ascontiguousarray(X.values), columns=X.columns) 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1) 

pipe1 = Pipeline([('scaler', StandardScaler()), 
                 ('regr', LinearRegression(fit_intercept = False, normalize=False, copy_X=False, n_jobs=-1))])


pipe1.fit(X_train, y_train)
print('In-sample Rsq: % .4f' % pipe1.score(X_train, y_train))
print('Out-of-sample Rsq: % .4f'% pipe1.score(X_test, y_test))
OLS_prediction = pipe1.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-b7332e44c887> in <module>
#      17
#      18
# ---> 19 pipe1.fit(X_train, y_train)
#      20 print('In-sample Rsq: % .4f' % pipe1.score(X_train, y_train))
#      21 print('Out-of-sample Rsq: % .4f'% pipe1.score(X_test, y_test))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     333             if self._final_estimator != 'passthrough':
#     334                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 335                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     336
#     337         return self
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# ...

# %%
# second check lasso

df_trade_work_lasso = df_trade_work.copy()
df_trade_work_lasso = df_trade_work_lasso[cols]
df_trade_work_lasso = df_trade_work_lasso.drop(['API_od'], axis=1)
df_trade_work_lasso
# Out:
#         iso_o iso_d  year          FLOW         GDP_o         GDP_d  \
# 289140    DNK   ESP  1997  5.927132e+08  1.060030e+11  3.595943e+11
# 289146    DNK   FRA  1997  1.358719e+09  1.060030e+11  8.922538e+11
# 289149    DNK   GBR  1997  1.959397e+09  1.060030e+11  8.835401e+11
# 289157    DNK   GRC  1997  2.444199e+08  1.060030e+11  8.744582e+10
# 289217    DNK   NLD  1997  9.613337e+08  1.060030e+11  2.517860e+11
# ...       ...   ...   ...           ...           ...           ...
# 1370457   GBR   FRA  1991  9.749256e+09  6.479831e+11  7.232636e+11
# 1370522   GBR   NLD  1991  6.182051e+09  6.479831e+11  1.833275e+11
# 1370626   GBR   DNK  1990  1.332809e+09  6.156479e+11  7.777185e+10
# 1370636   GBR   FRA  1990  9.520620e+09  6.156479e+11  7.182199e+11
# 1370701   GBR   NLD  1990  5.806918e+09  6.156479e+11  1.769883e+11
#
#                 POP_o         POP_d       IPTOT_o       IPTOT_d  ...  Evercol  \
# ...

# %%
# using Lasso to do out-of-sample prediction

y = df_trade_work_lasso['FLOW']
X = df_trade_work_lasso.iloc[:, 4:]

df_trade_work_lasso['c'] = 1

for j in ['FLOW', 'GDP_o', 'GDP_d', 'POP_o', 'POP_d','IPTOT_o','IPTOT_d', 'XPTOT_o', 'XPTOT_d', 'SH_PRIM_o', 'SH_SECD_o', 'SH_PRIM_d', 'SH_SECD_d', 'TARIFF_o', 'TARIFF_d', 'XCH_RATE_o', 'XCH_RATE_d', 'Distw', 'Dist_coord', 'Dist_o', 'Dist_d', 'SeaDist_SHRT', 'SeaDist_2CST', 'Comlang', 'Contig', 'Curcol_o', 'Curcol_d', 'Curcol', 'Evercol', 'OECD_o', 'OECD_d', 'EU_o', 'EU_d', 'GATT_o', 'GATT_d', 'GHG_od', 'API_o', 'API_d']:
    for i in ['FLOW', 'GDP_o', 'GDP_d', 'POP_o', 'POP_d','IPTOT_o','IPTOT_d', 'XPTOT_o', 'XPTOT_d', 'SH_PRIM_o', 'SH_SECD_o', 'SH_PRIM_d', 'SH_SECD_d', 'TARIFF_o', 'TARIFF_d', 'XCH_RATE_o', 'XCH_RATE_d', 'Distw', 'Dist_coord', 'Dist_o', 'Dist_d', 'SeaDist_SHRT', 'SeaDist_2CST', 'Comlang', 'Contig', 'Curcol_o', 'Curcol_d', 'Curcol', 'Evercol', 'OECD_o', 'OECD_d', 'EU_o', 'EU_d', 'GATT_o', 'GATT_d', 'GHG_od', 'API_o', 'API_d']:
        df_trade_work_lasso[f"{j[0:4]}_{i[0:4]}"] = df_trade_work_lasso[j]*df_trade_work_lasso[i]  
        
df_trade_work_lasso
# Out:
#         iso_o iso_d  year          FLOW         GDP_o         GDP_d  \
# 289140    DNK   ESP  1997  5.927132e+08  1.060030e+11  3.595943e+11
# 289146    DNK   FRA  1997  1.358719e+09  1.060030e+11  8.922538e+11
# 289149    DNK   GBR  1997  1.959397e+09  1.060030e+11  8.835401e+11
# 289157    DNK   GRC  1997  2.444199e+08  1.060030e+11  8.744582e+10
# 289217    DNK   NLD  1997  9.613337e+08  1.060030e+11  2.517860e+11
# ...       ...   ...   ...           ...           ...           ...
# 1370457   GBR   FRA  1991  9.749256e+09  6.479831e+11  7.232636e+11
# 1370522   GBR   NLD  1991  6.182051e+09  6.479831e+11  1.833275e+11
# 1370626   GBR   DNK  1990  1.332809e+09  6.156479e+11  7.777185e+10
# 1370636   GBR   FRA  1990  9.520620e+09  6.156479e+11  7.182199e+11
# 1370701   GBR   NLD  1990  5.806918e+09  6.156479e+11  1.769883e+11
#
#                 POP_o         POP_d       IPTOT_o       IPTOT_d  ...  \
# 289140    5284.991211  39582.414062  2.716382e+10  7.498196e+10  ...
# ...

# %%
from sklearn.preprocessing import StandardScaler 
from sklearn.pipeline import Pipeline 
from sklearn.linear_model import Lasso

X = pd.DataFrame(np.ascontiguousarray(X.values), columns=X.columns)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state = 1) 


pipe = Pipeline([('scaler', StandardScaler()),
                 ('lasso', 
                  Lasso(alpha=0.05, fit_intercept=True, normalize=False, copy_X=False, max_iter=10000))])

pipe.fit(X_train, y_train)
print('In-sample Rsq: % .4f'% pipe.score(X_train, y_train))
print('Out-of-sample Rsq: % .4f'% pipe.score(X_test, y_test))
# Out:
# In-sample Rsq:  0.8691
# Out-of-sample Rsq:  0.8670
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.385089189444487e+22, tolerance: 2.116939390356514e+19
#   model = cd_fast.enet_coordinate_descent(

# %%
imp = pd.DataFrame(pipe.named_steps['lasso'].coef_, columns = ['Lasso coefficient'])
imp['Feature'] = list(X_train.columns)
imp
# Out:
#     Lasso coefficient       Feature
# 0       -1.083446e+09         GDP_o
# 1       -2.401679e+09         GDP_d
# 2        1.824511e+09         POP_o
# 3        6.782278e+09         POP_d
# 4        1.273116e+09       IPTOT_o
# 5       -8.790486e+07       IPTOT_d
# 6        3.004039e+09       XPTOT_o
# 7        3.209423e+09       XPTOT_d
# 8        1.003850e+09     SH_PRIM_o
# 9       -4.008269e+08     SH_SECD_o
# 10       6.469988e+08     SH_PRIM_d
# 11      -9.105637e+08     SH_SECD_d
# 12      -4.322250e+08      TARIFF_o
# 13       4.715690e+08      TARIFF_d
# 14       8.802625e+08    XCH_RATE_o
# 15       1.552460e+09    XCH_RATE_d
# 16      -3.742314e+09         Distw
# 17       1.638679e+09    Dist_coord
# 18      -1.348971e+09        Dist_o
# 19       8.381938e+08        Dist_d
# 20      -6.339625e+09  SeaDist_SHRT
# 21       5.721168e+09  SeaDist_2CST
# 22       2.404761e+08       Comlang
# 23       2.428261e+09        Contig
# 24       0.000000e+00      Curcol_o
# ...

# %%
index = imp[(imp['Lasso coefficient'] == 0)].index
imp.drop(index, inplace=True)
imp
# Out:
#     Lasso coefficient       Feature
# 0       -1.083446e+09         GDP_o
# 1       -2.401679e+09         GDP_d
# 2        1.824511e+09         POP_o
# 3        6.782278e+09         POP_d
# 4        1.273116e+09       IPTOT_o
# 5       -8.790486e+07       IPTOT_d
# 6        3.004039e+09       XPTOT_o
# 7        3.209423e+09       XPTOT_d
# 8        1.003850e+09     SH_PRIM_o
# 9       -4.008269e+08     SH_SECD_o
# 10       6.469988e+08     SH_PRIM_d
# 11      -9.105637e+08     SH_SECD_d
# 12      -4.322250e+08      TARIFF_o
# 13       4.715690e+08      TARIFF_d
# 14       8.802625e+08    XCH_RATE_o
# 15       1.552460e+09    XCH_RATE_d
# 16      -3.742314e+09         Distw
# 17       1.638679e+09    Dist_coord
# 18      -1.348971e+09        Dist_o
# 19       8.381938e+08        Dist_d
# 20      -6.339625e+09  SeaDist_SHRT
# 21       5.721168e+09  SeaDist_2CST
# 22       2.404761e+08       Comlang
# 23       2.428261e+09        Contig
# 27       2.523645e+09       Evercol
# ...

# %%
# check CART

import matplotlib
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import KFold, cross_val_score
from sklearn.model_selection import train_test_split

from sklearn import ensemble
from sklearn import tree as tree

# %%
df_trade_work_CART = df_trade_work.copy()
df_trade_work_CART = df_trade_work_CART[cols]

# %%
# using CART to do out-of-sample prediction


y = df_trade_work_CART['FLOW'] 
X = df_trade_work_CART.iloc[:, 4:]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1) 

cart = tree.DecisionTreeRegressor(criterion='mse', min_samples_leaf = 1, min_impurity_decrease = 0, \
                                  min_samples_split=2, max_depth = None, random_state = 1)
cart = cart.fit(X_train, y_train)

y_pred = cart.predict(X_test)

print('Tree depth: %.0f' % cart.get_depth())
print('Out-of-sample Rsq: %.3f'% r2_score(y_test, y_pred))
print('Out-of-sample MSE: %.3f'% mean_squared_error(y_test, y_pred))


#dendrogram
matplotlib.rcParams.update({'font.size': 8, 'figure.figsize': (4, 2), 'figure.dpi': 300}) # set's parameters of the figure
tree.plot_tree(cart, max_depth = 3, filled = True, feature_names = list(X.columns),\
               fontsize = 3);
# Out:
# Tree depth: 17
# Out-of-sample Rsq: 1.000
# Out-of-sample MSE: 0.000

# %%
# finding out the optimal tree depth using cross validation

from sklearn.model_selection import cross_validate
import scipy as sp

def cv_iter(max_depth, max_leaf_nodes, min_samples_leafs, folds, X, y):
    kf = KFold(n_splits=folds, shuffle=True, random_state=1) 
    cart = tree.DecisionTreeRegressor(max_depth = max_depth, max_leaf_nodes = max_leaf_nodes, min_samples_leaf = min_samples_leafs, random_state = 1) # settings for CART
    cv_result = cross_validate(cart, X, y, scoring = 'neg_mean_squared_error') 
    avg_score = np.mean(cv_result['test_score']) 
    return float(-avg_score)

# %%
result = {}
for i in range(1, 30):
    result[i] = cv_iter(i, None, 2, 5, X_train, y_train) 

matplotlib.rcParams.update({'font.size': 8, 'figure.figsize': (4, 3), 'figure.dpi': 100})    
results = pd.DataFrame.from_dict(result,orient='index', columns = ['Test Score'])
results.plot.bar(color = 'DarkBlue')

results['Test Score'].idxmin()
# Out:
# 16

# %%
# using the optimal tree depth = 8

cart = tree.DecisionTreeRegressor(criterion='mse', min_samples_leaf = 2, min_impurity_decrease = 0, \
                                  min_samples_split=2, max_depth = 8, random_state = 1)
cart = cart.fit(X_train, y_train)

y_pred = cart.predict(X_test)

print('Tree depth: %.0f' % cart.get_depth())
print('Out-of-sample Rsq: %.3f'% r2_score(y_test, y_pred))
print('Out-of-sample MSE: %.3f'% mean_squared_error(y_test, y_pred))


#dendrogram
matplotlib.rcParams.update({'font.size': 8, 'figure.figsize': (4, 2), 'figure.dpi': 300}) 
tree.plot_tree(cart, max_depth = 8, filled = True, feature_names = list(X.columns),\
               fontsize = 3);
# Out:
# Tree depth: 8
# Out-of-sample Rsq: 0.997
# Out-of-sample MSE: 173888747259877152.000

# %%
# using random forest to do out-of-sample prediction

rf = ensemble.RandomForestRegressor(n_estimators = 100, min_samples_leaf = 2, oob_score = True, \
        random_state = 1)
rf = rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

print('Out-of-sample Rsq: %.3f'% r2_score(y_test, y_pred))
print('Out-of-sample MSE: %.3f'% mean_squared_error(y_test, y_pred))
# Out:
# Out-of-sample Rsq: 1.000
# Out-of-sample MSE: 1688246892834669.000

# %%
# finding out the optimal number of trees in the forest

def cv_iter(n, folds, X, y):
    kf = KFold(n_splits=folds, shuffle=True, random_state=1)
    rf = ensemble.RandomForestRegressor(n_estimators = n, min_samples_leaf = 1, \
        random_state = 1)
    cv_result = cross_validate(rf, X, y, scoring = 'neg_mean_squared_error')
    avg_score = np.mean(cv_result['test_score'])
    return float(-avg_score)

# %%
result = {}
for i in range(1, 200, 10):
    result[i] = cv_iter(i, 5, X_train, y_train)

matplotlib.rcParams.update({'font.size': 8, 'figure.figsize': (4, 3), 'figure.dpi': 100})    
results = pd.DataFrame.from_dict(result,orient='index', columns = ['Test Score'])
results.plot(color = 'DarkBlue')

# %%
# the optimal number of trees is 75

rf = ensemble.RandomForestRegressor(n_estimators = 75, min_samples_leaf = 2, oob_score = True, \
        random_state = 1)
rf = rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

print('Out-of-sample Rsq: %.3f'% r2_score(y_test, y_pred))
print('Out-of-sample MSE: %.3f'% mean_squared_error(y_test, y_pred))
# Out:
# Out-of-sample Rsq: 1.000
# Out-of-sample MSE: 1312026029194634.250

# %%
# we get very good out-of-sample fit and at the same time has a lower MSE value, avoiding potential overfitting problem

# %%
# important features selected by CART

imp = pd.DataFrame(cart.feature_importances_, columns = ['Feature importance'])
imp['Feature'] = list(X.columns)
imp.sort_values(by=['Feature importance'], ascending=False).reset_index(drop = True)
# Out:
#     Feature importance       Feature
# 0         3.824225e-01       IPTOT_o
# 1         2.137413e-01  SeaDist_2CST
# 2         1.765143e-01         GDP_d
# 3         4.109671e-02       Comlang
# 4         3.943158e-02        Dist_o
# 5         3.303775e-02  SeaDist_SHRT
# 6         2.153683e-02       IPTOT_d
# 7         2.109240e-02       Evercol
# 8         1.285538e-02         Distw
# 9         1.253886e-02       XPTOT_o
# 10        1.014184e-02    Dist_coord
# 11        8.586842e-03       XPTOT_d
# 12        5.274884e-03        Dist_d
# 13        4.208852e-03         API_d
# 14        3.751969e-03         POP_d
# 15        2.369085e-03     SH_PRIM_o
# 16        2.310572e-03         GDP_o
# 17        1.738780e-03     SH_PRIM_d
# 18        1.401761e-03        Contig
# 19        1.362789e-03         POP_o
# 20        1.234197e-03        API_od
# 21        9.622410e-04    XCH_RATE_o
# 22        9.027331e-04         API_o
# 23        7.698748e-04      TARIFF_o
# ...

# %%
# important features selected by rf

imp = pd.DataFrame(rf.feature_importances_, columns = ['Feature importance'])
imp['Feature'] = list(X.columns)
imp.sort_values(by=['Feature importance'], ascending=False).reset_index(drop = True)
# Out:
#     Feature importance       Feature
# 0             0.341286       IPTOT_o
# 1             0.165378         GDP_d
# 2             0.110044  SeaDist_SHRT
# 3             0.099712  SeaDist_2CST
# 4             0.037592       XPTOT_o
# 5             0.033900       Comlang
# 6             0.033305         Distw
# 7             0.033110       Evercol
# 8             0.030086       IPTOT_d
# 9             0.023241    Dist_coord
# 10            0.018990         POP_o
# 11            0.015167         POP_d
# 12            0.008501        Dist_o
# 13            0.006774     SH_PRIM_o
# 14            0.005914    XCH_RATE_o
# 15            0.005826        Dist_d
# 16            0.004560    XCH_RATE_d
# 17            0.003684         GDP_o
# 18            0.003328       XPTOT_d
# 19            0.003082        Contig
# 20            0.002678     SH_PRIM_d
# 21            0.002607     SH_SECD_o
# 22            0.002391         API_d
# 23            0.002017      TARIFF_d
# ...

# %%
# CART considers API_d as a more important feature than RF

# %%
# in our case, we don't really have to use ML methods to predict trade flow, because OLS can already preform quite good prediction
# conjecture: trade flow is quite persistent, meaning that we can use history data to predict future and that observations are not purely independent on each other
# for Non-parametric methods we need to assume independence between observations; if this assumption fails (e.g time-series analysis), parametric models will likely outperform
# in our case, ols outperforms LASSO in out-of-sample fit
# the outstanding performance from CART or RF comes from nonlinearity which allows interaction among variables (i.e country experiences higher GDP growth will also engage more in international trade)
# but if we manually add interaction term in LASSO, we actually get a little bit worse model performance
